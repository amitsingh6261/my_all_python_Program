# %% [markdown]
# <a href="https://colab.research.google.com/github/amitsingh6261/my_all_python_Program/blob/main/pandas_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_8=pd.read_csv("/content/all_alpha_08.csv")
df_18=pd.read_csv("/content/all_alpha_18.csv")

# %%
df_8
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# ...           ...    ...      ...      ...   ...       ...        ...  ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline         FA   B5
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         FA   B5
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         FA   B5
#
# ...

# %%
df_18
# Out:
#             Model  Displ  Cyl       Trans Drive                  Fuel  \
# 0       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 2       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD              Gasoline
# ...           ...    ...  ...         ...   ...                   ...
# 1606  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1607  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1608  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
#
#      Cert Region       Stnd            Stnd Description  Underhood ID  \
# ...

# %%
df_8.shape , df_18.shape
# Out:
# ((2404, 18), (1611, 18))

# %%
df_8.duplicated().sum(), df_18.duplicated().sum()
# Out:
# (np.int64(25), np.int64(0))

# %%
df_8.isnull().sum(), df_18.isnull().sum()
# Out:
# (Model                     0
#  Displ                     0
#  Cyl                     199
#  Trans                   199
#  Drive                    93
#  Fuel                      0
#  Sales Area                0
#  Stnd                      0
#  Underhood ID              0
#  Veh Class                 0
#  Air Pollution Score       0
#  FE Calc Appr            199
#  City MPG                199
#  Hwy MPG                 199
#  Cmb MPG                 199
#  Unadj Cmb MPG           199
#  Greenhouse Gas Score    199
#  SmartWay                  0
#  dtype: int64,
#  Model                   0
#  Displ                   2
#  Cyl                     2
#  Trans                   0
#  Drive                   0
#  Fuel                    0
#  Cert Region             0
#  Stnd                    0
#  Stnd Description        0
#  Underhood ID            0
#  Veh Class               0
#  Air Pollution Score     0
#  City MPG                0
#  Hwy MPG                 0
# ...

# %%
df_8.nunique(),df_18.nunique()
# Out:
# (Model                   436
#  Displ                    47
#  Cyl                       8
#  Trans                    14
#  Drive                     2
#  Fuel                      5
#  Sales Area                3
#  Stnd                     12
#  Underhood ID            343
#  Veh Class                 9
#  Air Pollution Score      13
#  FE Calc Appr              2
#  City MPG                 39
#  Hwy MPG                  43
#  Cmb MPG                  38
#  Unadj Cmb MPG           721
#  Greenhouse Gas Score     20
#  SmartWay                  2
#  dtype: int64,
#  Model                   367
#  Displ                    36
#  Cyl                       7
#  Trans                    26
#  Drive                     2
#  Fuel                      5
#  Cert Region               2
#  Stnd                     19
#  Stnd Description         19
#  Underhood ID            230
#  Veh Class                 9
#  Air Pollution Score       6
#  City MPG                 58
# ...

# %%
df_18.nunique()
# Out:
# Model                   367
# Displ                    36
# Cyl                       7
# Trans                    26
# Drive                     2
# Fuel                      5
# Cert Region               2
# Stnd                     19
# Stnd Description         19
# Underhood ID            230
# Veh Class                 9
# Air Pollution Score       6
# City MPG                 58
# Hwy MPG                  62
# Cmb MPG                  57
# Greenhouse Gas Score     10
# SmartWay                  3
# Comb CO2                299
# dtype: int64

# %%
df_8.columns
# Out:
# Index(['Model', 'Displ', 'Cyl', 'Trans', 'Drive', 'Fuel', 'Sales Area', 'Stnd',
#        'Underhood ID', 'Veh Class', 'Air Pollution Score', 'FE Calc Appr',
#        'City MPG', 'Hwy MPG', 'Cmb MPG', 'Unadj Cmb MPG',
#        'Greenhouse Gas Score', 'SmartWay'],
#       dtype='object')

# %%
df_18.columns
# Out:
# Index(['Model', 'Displ', 'Cyl', 'Trans', 'Drive', 'Fuel', 'Cert Region',
#        'Stnd', 'Stnd Description', 'Underhood ID', 'Veh Class',
#        'Air Pollution Score', 'City MPG', 'Hwy MPG', 'Cmb MPG',
#        'Greenhouse Gas Score', 'SmartWay', 'Comb CO2'],
#       dtype='object')

# %%
df_8.drop(columns=['Stnd', 'Underhood ID','FE Calc Appr','Unadj Cmb MPG'],inplace=True)
df_18.drop(columns=['Stnd','Stnd Description', 'Underhood ID', 'Comb CO2'],inplace=True)

# %%
df_8.rename(columns={'sales_area':'cert_region'},inplace=True)

# %%
df_8.rename(columns=lambda x: x.strip().lower().replace(" ","_"),inplace=True)
df_18.rename(columns=lambda x: x.strip().lower().replace(" ","_"),inplace=True)

# %%
df_18.head(1)
# Out:
#        model  displ  cyl       trans drive      fuel cert_region  veh_class  \
# 0  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          FA  small SUV
#
#    air_pollution_score city_mpg hwy_mpg cmb_mpg  greenhouse_gas_score smartway
# 0                    3       20      28      23                     5       No

# %%
df_8.head(1)
# Out:
#        model  displ      cyl    trans drive      fuel cert_region veh_class  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA       SUV
#
#   air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 0                   7       15      20      17                    4       no

# %%
df_8.columns == df_18.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %%
(df_8.columns == df_18.columns).all()
# Out:
# np.True_

# %%
df_8.columns
# Out:
# Index(['model', 'displ', 'cyl', 'trans', 'drive', 'fuel', 'sales_area',
#        'veh_class', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg',
#        'greenhouse_gas_score', 'smartway'],
#       dtype='object')

# %%
df_18.columns
# Out:
# Index(['model', 'displ', 'cyl', 'trans', 'drive', 'fuel', 'cert_region',
#        'veh_class', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg',
#        'greenhouse_gas_score', 'smartway'],
#       dtype='object')

# %%
#jo data per operation kiye hai us data ko download karne ke liye matlab (filter data download krne ke liye)
df_8.to_csv('data_8_V1.csv' , index=False)
df_18.to_csv('data_18_V1.csv' , index=False)

# %%
# show filter data
df_8=pd.read_csv('/content/data_8_V1.csv')
df_18=pd.read_csv('/content/data_18_V1.csv')

# %%
df_8
# Out:
#       Unnamed: 0        model  displ      cyl    trans drive      fuel  \
# 0              0    ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline
# 1              1    ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline
# 2              2    ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline
# 3              3    ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline
# 4              4     ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline
# ...          ...          ...    ...      ...      ...   ...       ...
# 2399        2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline
# 2400        2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline
# 2401        2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline
# 2402        2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline
# 2403        2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline
#
#      cert_region    veh_class air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# ...

# %%
df_8.query('cert_region == "CA"').head()
# Out:
#    Unnamed: 0      model  displ      cyl    trans drive      fuel cert_region  \
# 0           0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# 2           2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          CA
# 4           4   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# 6           6   ACURA TL    3.2  (6 cyl)  Auto-S5   2WD  Gasoline          CA
# 7           7   ACURA TL    3.5  (6 cyl)  Auto-S5   2WD  Gasoline          CA
#
#      veh_class air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# 0          SUV                   7       15      20      17
# 2          SUV                   7       17      22      19
# 4  midsize car                   7       16      24      19
# 6  midsize car                   7       18      26      21
# 7  midsize car                   7       17      26      20
#
#   greenhouse_gas_score smartway
# 0                    4       no
# 2                    5       no
# 4                    5       no
# ...

# %%
df_8.drop(['cert_region'],axis =1, inplace=True)
df_18.drop(['cert_region'],axis =1, inplace=True)

# %%
df_8.isnull().sum()
# Out:
# Unnamed: 0                0
# model                     0
# displ                     0
# cyl                     199
# trans                   199
# drive                    93
# fuel                      0
# veh_class                 0
# air_pollution_score       0
# city_mpg                199
# hwy_mpg                 199
# cmb_mpg                 199
# greenhouse_gas_score    199
# smartway                  0
# dtype: int64

# %%
df_8.dropna(inplace=True)

# %%
df_8.isnull().sum()
# Out:
# Unnamed: 0              0
# model                   0
# displ                   0
# cyl                     0
# trans                   0
# drive                   0
# fuel                    0
# veh_class               0
# air_pollution_score     0
# city_mpg                0
# hwy_mpg                 0
# cmb_mpg                 0
# greenhouse_gas_score    0
# smartway                0
# dtype: int64

# %%
df_18.isnull().sum()
# Out:
# Unnamed: 0              0
# model                   0
# displ                   2
# cyl                     2
# trans                   0
# drive                   0
# fuel                    0
# veh_class               0
# air_pollution_score     0
# city_mpg                0
# hwy_mpg                 0
# cmb_mpg                 0
# greenhouse_gas_score    0
# smartway                0
# dtype: int64

# %%
df_18.dropna(inplace=True)

# %%
df_18.isnull().sum()
# Out:
# Unnamed: 0              0
# model                   0
# displ                   0
# cyl                     0
# trans                   0
# drive                   0
# fuel                    0
# veh_class               0
# air_pollution_score     0
# city_mpg                0
# hwy_mpg                 0
# cmb_mpg                 0
# greenhouse_gas_score    0
# smartway                0
# dtype: int64

# %%
df_8.isnull().sum()==df_18.isnull().sum()
# Out:
# Unnamed: 0              True
# model                   True
# displ                   True
# cyl                     True
# trans                   True
# drive                   True
# fuel                    True
# veh_class               True
# air_pollution_score     True
# city_mpg                True
# hwy_mpg                 True
# cmb_mpg                 True
# greenhouse_gas_score    True
# smartway                True
# dtype: bool

# %%
df_8.isnull().sum().any()==df_18.isnull().sum().any()

# %%
df_8.duplicated().sum(), df_18.duplicated().sum()
# Out:
# (np.int64(0), np.int64(0))

# %%
df_8.drop_duplicates(inplace=True)
df_18.drop_duplicates(inplace=True)

# %%
df_8.duplicated().sum(), df_18.duplicated().sum()
# Out:
# (np.int64(0), np.int64(0))

# %%
df_8.to_csv('data_8_V2.csv' , index=False)
df_18.to_csv('data_18_V2.csv' , index=False)

# %%
df_8=pd.read_csv('/content/data_8_V2.csv')
df_18=pd.read_csv('/content/data_18_V2.csv')

# %%
df_8
# Out:
#       Unnamed: 0        model  displ      cyl    trans drive      fuel  \
# 0              0    ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline
# 1              1    ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline
# 2              2    ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline
# 3              3    ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline
# 4              4     ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline
# ...          ...          ...    ...      ...      ...   ...       ...
# 2200        2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline
# 2201        2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline
# 2202        2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline
# 2203        2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline
# 2204        2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline
#
#         veh_class air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# ...

# %%
df_18
# Out:
#       Unnamed: 0        model  displ  cyl       trans drive  \
# 0              0    ACURA RDX    3.5  6.0  SemiAuto-6   2WD
# 1              1    ACURA RDX    3.5  6.0  SemiAuto-6   2WD
# 2              2    ACURA RDX    3.5  6.0  SemiAuto-6   4WD
# 3              3    ACURA RDX    3.5  6.0  SemiAuto-6   4WD
# 4              4    ACURA TLX    2.4  4.0       AMS-8   2WD
# ...          ...          ...    ...  ...         ...   ...
# 1604        1606  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD
# 1605        1607  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD
# 1606        1608  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD
# 1607        1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD
# 1608        1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD
#
#                       fuel     veh_class  air_pollution_score city_mpg  \
# 0                 Gasoline     small SUV                    3       20
# 1                 Gasoline     small SUV                    3       20
# ...
