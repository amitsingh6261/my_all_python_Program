# %% [markdown]
# <a href="https://colab.research.google.com/github/amitsingh6261/my_all_python_Program/blob/main/pattern.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(5):

    for j in range(5-i):

        print("*",end=" ")



    print()
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
for i in range (5):
  print("x "*i)
# Out:
#  x
#  x  x
#  x  x  x
#  x  x  x  x

# %%
for i in range (4,0,-1):
  print("# "*i)
# Out:
# # # # #
# # # #
# # #
# #

# %%
# q q q q
# q q q
# q q
# q
# q q
# q q q
# q q q q

# %%
for i in range(4): #for row
 for j in range (4): #for column
  if i<2:
    if j%2==0:  #first two row
     print("a",end=" ")
    else:
     print("b",end=" ")
  else:
    if j%2==0: #second two row
      print("b",end=" ")
    else:
       print("a",end=" ")
 print()
# Out:
# a b a b
# a b a b
# b a b a
# b a b a
